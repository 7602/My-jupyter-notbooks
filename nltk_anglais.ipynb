# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')

from nltk.corpus import stopwords
stopwords.words('english')
file = """Perhaps one of the most significant advances made by Arabic mathematics began at this time with the work of al-Khwarizmi, namely
the beginnings of algebra. It is important to understand just how significant this new idea was. It was a revolutionary move away from
the Greek concept of mathematics which was essentially geometry. Algebra was a unifying theory which allowed rational
numbers, irrational numbers, geometrical magnitudes, etc., to all be treated as "algebraic objects". It gave mathematics a whole new
development path so much broader in concept to that which had existed before, and provided a vehicle for future development of the
subject. Another important aspect of the introduction of algebraic ideas was that it allowed mathematics to be applied to itself in a
way which had not happened before."""


#tokenazition 
tokens = nltk.word_tokenize(file)
tokens

#supprimer les ponctuations
import re
punctuation = re.compile(r'[-.?!,:;()[0-9]]')
post_punctuation = []
for words in tokens:
    word = punctuation.sub("",words)
    if len(word)>0:
        post_punctuation.append(word)
post_punctuation 

#compter la fréquence d'un mot
from nltk.probability import FreqDist
fdist = FreqDist()
for word in tokens:
    fdist[word.lower()]+=1
fdist  


#pos tagging
tagged = nltk.pos_tag(tokens)
tagged

#stemming
from nltk.stem.porter import PorterStemmer
porter_stemmer  = PorterStemmer()
for w in tokens:
    print(w, ':' ,porter_stemmer.stem(w))
    
#lemmatization
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
for w in tokens:
    print(" {0:20} {1:20}".format(w, wordnet_lemmatizer.lemmatize(w)))  
    
    
#chunking
grammar_np = r"NP : {<DT>?<JJ>*<NN>}"
chunk_parser = nltk.RegexpParser(grammar_np)
chunk_result = chunk_parser.parse(tagged)
chunk_result
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Perhaps : perhap
# one : one
# of : of
# the : the
# most : most
# significant : signific
# advances : advanc
# made : made
# by : by
# Arabic : arab
# mathematics : mathemat
# began : began
# at : at
# this : thi
# time : time
# with : with
# the : the
# work : work
# of : of
# al-Khwarizmi : al-khwarizmi
# , : ,
# namely : name
# the : the
# beginnings : begin
# of : of
# algebra : algebra
# . : .
# It : it
# is : is
# important : import
# to : to
# understand : understand
# just : just
# how : how
# significant : signific
# this : thi
# new : new
# idea : idea
# was : wa
# . : .
# It : it
# was : wa
# a : a
# revolutionary : revolutionari
# move : move
# away : away
# from : from
# the : the
# Greek : greek
# concept : concept
# of : of
# mathematics : mathemat
# which : which
# was : wa
# essentially : essenti
# geometry : geometri
# . : .
# Algebra : algebra
# was : wa
# a : a
# unifying : unifi
# theory : theori
# which : which
# allowed : allow
# rational : ration
# numbers : number
# , : ,
# irrational : irrat
# numbers : number
# , : ,
# geometrical : geometr
# magnitudes : magnitud
# , : ,
# etc. : etc.
# , : ,
# to : to
# all : all
# be : be
# treated : treat
# as : as
# `` : ``
# algebraic : algebra
# objects : object
# '' : ''
# . : .
# It : it
# gave : gave
# mathematics : mathemat
# a : a
# whole : whole
# new : new
# development : develop
# path : path
# so : so
# much : much
# broader : broader
# in : in
# concept : concept
# to : to
# that : that
# which : which
# had : had
# existed : exist
# before : befor
# , : ,
# and : and
# provided : provid
# a : a
# vehicle : vehicl
# for : for
# future : futur
# development : develop
# of : of
# the : the
# subject : subject
# . : .
# Another : anoth
# important : import
# aspect : aspect
# of : of
# the : the
# introduction : introduct
# of : of
# algebraic : algebra
# ideas : idea
# was : wa
# that : that
# it : it
# allowed : allow
# mathematics : mathemat
# to : to
# be : be
# applied : appli
# to : to
# itself : itself
# in : in
# a : a
# way : way
# which : which
# had : had
# not : not
# happened : happen
# before : befor
# . : .
#  Perhaps              Perhaps
#  one                  one
#  of                   of
#  the                  the
#  most                 most
#  significant          significant
#  advances             advance
#  made                 made
#  by                   by
#  Arabic               Arabic
#  mathematics          mathematics
#  began                began
#  at                   at
#  this                 this
#  time                 time
#  with                 with
#  the                  the
#  work                 work
#  of                   of
#  al-Khwarizmi         al-Khwarizmi
#  ,                    ,
#  namely               namely
#  the                  the
#  beginnings           beginning
#  of                   of
#  algebra              algebra
#  .                    .
#  It                   It
#  is                   is
#  important            important
#  to                   to
#  understand           understand
#  just                 just
#  how                  how
#  significant          significant
#  this                 this
#  new                  new
#  idea                 idea
#  was                  wa
#  .                    .
#  It                   It
#  was                  wa
#  a                    a
#  revolutionary        revolutionary
#  move                 move
#  away                 away
#  from                 from
#  the                  the
#  Greek                Greek
#  concept              concept
#  of                   of
#  mathematics          mathematics
#  which                which
#  was                  wa
#  essentially          essentially
#  geometry             geometry
#  .                    .
#  Algebra              Algebra
#  was                  wa
#  a                    a
#  unifying             unifying
#  theory               theory
#  which                which
#  allowed              allowed
#  rational             rational
#  numbers              number
#  ,                    ,
#  irrational           irrational
#  numbers              number
#  ,                    ,
#  geometrical          geometrical
#  magnitudes           magnitude
#  ,                    ,
#  etc.                 etc.
#  ,                    ,
#  to                   to
#  all                  all
#  be                   be
#  treated              treated
#  as                   a
#  ``                   ``
#  algebraic            algebraic
#  objects              object
#  ''                   ''
#  .                    .
#  It                   It
#  gave                 gave
#  mathematics          mathematics
#  a                    a
#  whole                whole
#  new                  new
#  development          development
#  path                 path
#  so                   so
#  much                 much
#  broader              broader
#  in                   in
#  concept              concept
#  to                   to
#  that                 that
#  which                which
#  had                  had
#  existed              existed
#  before               before
#  ,                    ,
#  and                  and
#  provided             provided
#  a                    a
#  vehicle              vehicle
#  for                  for
#  future               future
#  development          development
#  of                   of
#  the                  the
#  subject              subject
#  .                    .
#  Another              Another
#  important            important
#  aspect               aspect
#  of                   of
#  the                  the
#  introduction         introduction
#  of                   of
#  algebraic            algebraic
#  ideas                idea
#  was                  wa
#  that                 that
#  it                   it
#  allowed              allowed
#  mathematics          mathematics
#  to                   to
#  be                   be
#  applied              applied
#  to                   to
#  itself               itself
#  in                   in
#  a                    a
#  way                  way
#  which                which
#  had                  had
#  not                  not
#  happened             happened
#  before               before
#  .                    .
# The Ghostscript executable isn't found.
# See http://web.mit.edu/ghostscript/www/Install.htm
# If you're using a Mac, you can try installing
# https://docs.brew.sh/Installation then `brew install ghostscript`
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\tree.py in _repr_png_(self)
#     817                     [
# --> 818                         find_binary(
#     819                             "gs",
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\internals.py in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     687 ):
# --> 688     return next(
#     689         find_binary_iter(
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\internals.py in find_binary_iter(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     672     """
# --> 673     for file in find_file_iter(
#     674         path_to_bin or name, env_vars, searchpath, binary_names, url, verbose
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\internals.py in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     631         div = "=" * 75
# --> 632         raise LookupError("\n\n%s\n%s\n%s" % (div, msg, div))
#     633
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the gs file!
# Use software specific configuration paramaters or set the PATH environment variable.
# ===========================================================================
#
# The above exception was the direct cause of the following exception:
#
# LookupError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\tree.py in _repr_png_(self)
#     835                 )
#     836                 print(pre_error_message, file=sys.stderr)
# --> 837                 raise LookupError from e
#     838
#     839             with open(out_path, "rb") as sr:
#
# LookupError:
# Tree('S', [('Perhaps', 'RB'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('significant', 'JJ'), ('advances', 'NNS'), ('made', 'VBN'), ('by', 'IN'), ('Arabic', 'NNP'), ('mathematics', 'NNS'), ('began', 'VBD'), ('at', 'IN'), Tree('NP', [('this', 'DT'), ('time', 'NN')]), ('with', 'IN'), Tree('NP', [('the', 'DT'), ('work', 'NN')]), ('of', 'IN'), ('al-Khwarizmi', 'JJ'), (',', ','), ('namely', 'RB'), ('the', 'DT'), ('beginnings', 'NNS'), ('of', 'IN'), Tree('NP', [('algebra', 'NN')]), ('.', '.'), ('It', 'PRP'), ('is', 'VBZ'), ('important', 'JJ'), ('to', 'TO'), ('understand', 'VB'), ('just', 'RB'), ('how', 'WRB'), ('significant', 'JJ'), Tree('NP', [('this', 'DT'), ('new', 'JJ'), ('idea', 'NN')]), ('was', 'VBD'), ('.', '.'), ('It', 'PRP'), ('was', 'VBD'), Tree('NP', [('a', 'DT'), ('revolutionary', 'JJ'), ('move', 'NN')]), ('away', 'RB'), ('from', 'IN'), ('the', 'DT'), ('Greek', 'NNP'), Tree('NP', [('concept', 'NN')]), ('of', 'IN'), ('mathematics', 'NNS'), ('which', 'WDT'), ('was', 'VBD'), ('essentially', 'RB'), ('geometry', 'JJ'), ('.', '.'), ('Algebra', 'NNP'), ('was', 'VBD'), Tree('NP', [('a', 'DT'), ('unifying', 'JJ'), ('theory', 'NN')]), ('which', 'WDT'), ('allowed', 'VBD'), ('rational', 'JJ'), ('numbers', 'NNS'), (',', ','), ('irrational', 'JJ'), ('numbers', 'NNS'), (',', ','), ('geometrical', 'JJ'), ('magnitudes', 'NNS'), (',', ','), Tree('NP', [('etc.', 'NN')]), (',', ','), ('to', 'TO'), ('all', 'DT'), ('be', 'VB'), ('treated', 'VBN'), ('as', 'IN'), ('``', '``'), ('algebraic', 'JJ'), ('objects', 'NNS'), ("''", "''"), ('.', '.'), ('It', 'PRP'), ('gave', 'VBD'), ('mathematics', 'NNS'), Tree('NP', [('a', 'DT'), ('whole', 'JJ'), ('new', 'JJ'), ('development', 'NN')]), Tree('NP', [('path', 'NN')]), ('so', 'RB'), ('much', 'JJ'), ('broader', 'JJR'), ('in', 'IN'), Tree('NP', [('concept', 'NN')]), ('to', 'TO'), ('that', 'DT'), ('which', 'WDT'), ('had', 'VBD'), ('existed', 'VBN'), ('before', 'IN'), (',', ','), ('and', 'CC'), ('provided', 'VBD'), Tree('NP', [('a', 'DT'), ('vehicle', 'NN')]), ('for', 'IN'), Tree('NP', [('future', 'JJ'), ('development', 'NN')]), ('of', 'IN'), Tree('NP', [('the', 'DT'), ('subject', 'NN')]), ('.', '.'), Tree('NP', [('Another', 'DT'), ('important', 'JJ'), ('aspect', 'NN')]), ('of', 'IN'), Tree('NP', [('the', 'DT'), ('introduction', 'NN')]), ('of', 'IN'), ('algebraic', 'JJ'), ('ideas', 'NNS'), ('was', 'VBD'), ('that', 'IN'), ('it', 'PRP'), ('allowed', 'VBD'), ('mathematics', 'NNS'), ('to', 'TO'), ('be', 'VB'), ('applied', 'VBN'), ('to', 'TO'), ('itself', 'PRP'), ('in', 'IN'), Tree('NP', [('a', 'DT'), ('way', 'NN')]), ('which', 'WDT'), ('had', 'VBD'), ('not', 'RB'), ('happened', 'VBN'), ('before', 'IN'), ('.', '.')])
